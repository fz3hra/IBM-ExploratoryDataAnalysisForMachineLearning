# %% [markdown]
# Brief description of the data set and a summary of its attributes.
#
#
# Initial plan for data exploration.
#
#
# Actions taken for data cleaning and feature engineering..
#
# Key Findings and Insights, which synthesizes the results of Exploratory Data Analysis in an insightful and actionable manner
# Formulating at least 3 hypothesis about this data.
#
#
# Conducting a formal significance test for one of the hypotheses and discuss the results.
#
# Suggestions for next steps in analyzing this data.
#
# A paragraph that summarizes the quality of this data set and a request for additional data if needed.

# %% [markdown]
# #### plan for Data Exploration
#
# Why perform EDA?
# - so  as to get an insight about the data before training the mode using it
#
# Libraries to be used:
# - Pandas: build on top of Numpy and is used to handle and manipulate datasets.
# - Numpy: used to perform mathematical operation on data and handle multi dim\n
#     array and matrix.
# - Matplotlib: plotting lib that allows us to visualise our data so that we can
#     get more insights about it.
# - seaborn: plotting lib built on top of matplotlib and allows to create
#     attractive plots.
#
# How to gain insights about data?
# - do visualisation.
#
# Tools used for visualisation?
# - Countplot
# - Heatmap
# - Boxplt
# - Distplot
# - Pairplot

# %%
# importing libraries

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# importing dataset - complete

data = pd.read_csv('data/ufo_sighting_data.csv', error_bad_lines=False)
data.head()
# Out:
# D:\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (5,9) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           Date_time                  city state/province country UFO_shape  \
# 0  10/10/1949 20:30            san marcos             tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb             tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)            NaN      gb    circle
# 3  10/10/1956 21:00                  edna             tx      us    circle
# 4  10/10/1960 20:00               kaneohe             hi      us     light
#
#   length_of_encounter_seconds described_duration_of_encounter  \
# 0                        2700                      45 minutes
# 1                        7200                         1-2 hrs
# 2                          20                      20 seconds
# 3                          20                        1/2 hour
# 4                         900                      15 minutes
#
#                                          description date_documented  \
# 0  This event took place in early fall around 194...       4/27/2004
# 1  1949 Lackland AFB&#44 TX.  Lights racing acros...      12/16/2005
# 2  Green/Orange circular disc over Chester&#44 En...       1/21/2008
# 3  My older brother and twin sister were leaving ...       1/17/2004
# 4  AS a Marine 1st Lt. flying an FJ4B fighter/att...       1/22/2004
#
#      latitude   longitude
# 0  29.8830556  -97.941111
# 1    29.38421  -98.581082
# 2        53.2   -2.916667
# 3  28.9783333  -96.645833
# 4  21.4180556 -157.803611

# %%
# checking how many columns there are.
data.columns
# Out:
# Index(['Date_time', 'city', 'state/province', 'country', 'UFO_shape',
#        'length_of_encounter_seconds', 'described_duration_of_encounter',
#        'description', 'date_documented', 'latitude', 'longitude'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date_time                           object
# city                                object
# state/province                      object
# country                             object
# UFO_shape                           object
# length_of_encounter_seconds         object
# described_duration_of_encounter     object
# description                         object
# date_documented                     object
# latitude                            object
# longitude                          float64
# dtype: object

# %%
# shows statistica values like count, std deviation, mean, max, min,..

data.describe()
# Out:
#           longitude
# count  80332.000000
# mean     -86.772885
# std       39.697205
# min     -176.658056
# 25%     -112.073333
# 50%      -87.903611
# 75%      -78.755000
# max      178.441900

# %%
# checking for missing values:
data.isnull().sum()
# Out:
# Date_time                             0
# city                                  0
# state/province                     5797
# country                            9670
# UFO_shape                          1932
# length_of_encounter_seconds           0
# described_duration_of_encounter       0
# description                          15
# date_documented                       0
# latitude                              0
# longitude                             0
# dtype: int64

# %%
# we have missing values, therefore we need to clean it up:
#need to clean: state, country, shape, duration(seconds), duration(hours/min), comments.

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        80332 non-null  object
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80332 non-null  object
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  object
#  9   latitude                         80332 non-null  object
#  10  longitude                        80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %% [markdown]
# ### Cleaning data:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        80332 non-null  object
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80332 non-null  object
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  object
#  9   latitude                         80332 non-null  object
#  10  longitude                        80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
#2. date_time and date_documented needs to be in time
# therefore conversion will be required

data['Date_time'] = pd.to_datetime(data.Date_time, errors='coerce')
data['date_documented'] = pd.to_datetime(data.date_documented, errors='coerce')

# %%
data.Date_time
# Out:
# 0       1949-10-10 20:30:00
# 1       1949-10-10 21:00:00
# 2       1955-10-10 17:00:00
# 3       1956-10-10 21:00:00
# 4       1960-10-10 20:00:00
#                 ...
# 80327   2013-09-09 21:15:00
# 80328   2013-09-09 22:00:00
# 80329   2013-09-09 22:00:00
# 80330   2013-09-09 22:20:00
# 80331   2013-09-09 23:00:00
# Name: Date_time, Length: 80332, dtype: datetime64[ns]

# %%
data.date_documented
# Out:
# 0       2004-04-27
# 1       2005-12-16
# 2       2008-01-21
# 3       2004-01-17
# 4       2004-01-22
#            ...
# 80327   2013-09-30
# 80328   2013-09-30
# 80329   2013-09-30
# 80330   2013-09-30
# 80331   2013-09-30
# Name: date_documented, Length: 80332, dtype: datetime64[ns]

# %%
#3. change described_duration_of_encounter to mins or hours -> shouldnt be in seconds..

# --------------

# extracting year, month, weekday of date_time and date_documented

data['yearOfSighting'] = pd.DatetimeIndex(data.date_time).year

# %%
data['monthOfSighting'] = pd.DatetimeIndex(data.date_time).month

# %%
data['weekOfSighting'] = pd.DatetimeIndex(data.date_time).weekday

# %%
data['dayOfSighting'] = pd.DatetimeIndex(data.date_time).day

# %%
data['yearOfDocumenting'] = pd.DatetimeIndex(data.date_documented).year

# %%
data['monthOfDocumenting'] = pd.DatetimeIndex(data.date_documented).month

# %%
data['weekOfDocumenting'] = pd.DatetimeIndex(data.date_documented).weekday

# %%
data['dayOfDocumenting'] = pd.DatetimeIndex(data.date_documented).day

# %%
# data

# %%
# 4. lattitude  should be in float64 

# data['latitude'].astype('float') -> will not work if data is not clean or if a numeric value is to be converted to a string 
# object

data['latitude']=pd.to_numeric(data['latitude'], errors='coerce')

# converting length_of_encounter_seconds	 to float
data['length_of_encounter_seconds']=pd.to_numeric(data['length_of_encounter_seconds'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        80332 non-null  object
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80329 non-null  float64
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80331 non-null  float64
#  10  longitude                        80332 non-null  float64
#  11  date_time                        79638 non-null  datetime64[ns]
#  12  yearOfSighting                   79638 non-null  float64
#  13  monthOfSighting                  79638 non-null  float64
#  14  weekOfSighting                   79638 non-null  float64
#  15  dayOfSighting                    79638 non-null  float64
#  16  yearOfDocumenting                80332 non-null  int64
#  17  monthOfDocumenting               80332 non-null  int64
#  18  weekOfDocumenting                80332 non-null  int64
#  19  dayOfDocumenting                 80332 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(4), object(7)
# memory usage: 12.3+ MB

# %%
data
# Out:
#               Date_time                  city state/province country  \
# 0      10/10/1949 20:30            san marcos             tx      us
# 1      10/10/1949 21:00          lackland afb             tx     NaN
# 2      10/10/1955 17:00  chester (uk/england)            NaN      gb
# 3      10/10/1956 21:00                  edna             tx      us
# 4      10/10/1960 20:00               kaneohe             hi      us
# ...                 ...                   ...            ...     ...
# 80327    9/9/2013 21:15             nashville             tn      us
# 80328    9/9/2013 22:00                 boise             id      us
# 80329    9/9/2013 22:00                  napa             ca      us
# 80330    9/9/2013 22:20                vienna             va      us
# 80331    9/9/2013 23:00                edmond             ok      us
#
#       UFO_shape  length_of_encounter_seconds described_duration_of_encounter  \
# 0      cylinder                       2700.0                      45 minutes
# 1         light                       7200.0                         1-2 hrs
# 2        circle                         20.0                      20 seconds
# 3        circle                         20.0                        1/2 hour
# 4         light                        900.0                      15 minutes
# ...         ...                          ...                             ...
# 80327     light                        600.0                      10 minutes
# 80328    circle                       1200.0                      20 minutes
# 80329     other                       1200.0                            hour
# 80330    circle                          5.0                       5 seconds
# 80331     cigar                       1020.0                      17 minutes
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...      2004-04-27
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...      2005-12-16
# 2      Green/Orange circular disc over Chester&#44 En...      2008-01-21
# 3      My older brother and twin sister were leaving ...      2004-01-17
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...      2004-01-22
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...      2013-09-30
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...      2013-09-30
# 80329                                       Napa UFO&#44      2013-09-30
# 80330  Saw a five gold lit cicular craft moving fastl...      2013-09-30
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...      2013-09-30
#
#         latitude  ...           date_time yearOfSighting  monthOfSighting  \
# 0      29.883056  ... 1949-10-10 20:30:00         1949.0             10.0
# 1      29.384210  ... 1949-10-10 21:00:00         1949.0             10.0
# 2      53.200000  ... 1955-10-10 17:00:00         1955.0             10.0
# 3      28.978333  ... 1956-10-10 21:00:00         1956.0             10.0
# 4      21.418056  ... 1960-10-10 20:00:00         1960.0             10.0
# ...          ...  ...                 ...            ...              ...
# 80327  36.165833  ... 2013-09-09 21:15:00         2013.0              9.0
# 80328  43.613611  ... 2013-09-09 22:00:00         2013.0              9.0
# 80329  38.297222  ... 2013-09-09 22:00:00         2013.0              9.0
# 80330  38.901111  ... 2013-09-09 22:20:00         2013.0              9.0
# 80331  35.652778  ... 2013-09-09 23:00:00         2013.0              9.0
#
#        weekOfSighting  dayOfSighting  yearofDocumenting  yearOfDocumenting  \
# 0                 0.0           10.0             1949.0               2004
# 1                 0.0           10.0             1949.0               2005
# 2                 0.0           10.0             1955.0               2008
# 3                 2.0           10.0             1956.0               2004
# 4                 0.0           10.0             1960.0               2004
# ...               ...            ...                ...                ...
# 80327             0.0            9.0             2013.0               2013
# 80328             0.0            9.0             2013.0               2013
# 80329             0.0            9.0             2013.0               2013
# 80330             0.0            9.0             2013.0               2013
# 80331             0.0            9.0             2013.0               2013
#
#        monthOfDocumenting  weekOfDocumenting  dayOfDocumenting
# 0                       4                  1                27
# 1                      12                  4                16
# 2                       1                  0                21
# 3                       1                  5                17
# 4                       1                  3                22
# ...                   ...                ...               ...
# 80327                   9                  0                30
# 80328                   9                  0                30
# 80329                   9                  0                30
# 80330                   9                  0                30
# 80331                   9                  0                30
#
# [80332 rows x 21 columns]

# %%
mean = data.DataFrame.mean('state/province')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-7fb02066befe> in <module>
# ----> 1 mean = data.DataFrame.mean('state/province')
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'DataFrame'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 20 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        79638 non-null  datetime64[ns]
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80329 non-null  float64
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80331 non-null  float64
#  10  longitude                        80332 non-null  float64
#  11  date_time                        79638 non-null  datetime64[ns]
#  12  yearOfSighting                   79638 non-null  float64
#  13  monthOfSighting                  79638 non-null  float64
#  14  weekOfSighting                   79638 non-null  float64
#  15  dayOfSighting                    79638 non-null  float64
#  16  yearOfDocumenting                80332 non-null  int64
#  17  monthOfDocumenting               80332 non-null  int64
#  18  weekOfDocumenting                80332 non-null  int64
#  19  dayOfDocumenting                 80332 non-null  int64
# dtypes: datetime64[ns](3), float64(7), int64(4), object(6)
# memory usage: 12.3+ MB

# %%
# deleting date_time as it was added by mistake:
data.drop('date_time', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-162-5ecf224e0aa5> in <module>
#       1 # deleting date_time as it was added by mistake:
# ----> 2 data.drop('date_time', axis=1, inplace=True)
#
# D:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# D:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4186                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4187             else:
# -> 4188                 new_axis = axis.drop(labels, errors=errors)
#    4189             result = self.reindex(**{axis_name: new_axis})
#    4190
#
# D:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['date_time'] not found in axis"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        79638 non-null  datetime64[ns]
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80329 non-null  float64
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80331 non-null  float64
#  10  longitude                        80332 non-null  float64
#  11  yearOfSighting                   79638 non-null  float64
#  12  monthOfSighting                  79638 non-null  float64
#  13  weekOfSighting                   79638 non-null  float64
#  14  dayOfSighting                    79638 non-null  float64
#  15  yearOfDocumenting                80332 non-null  int64
#  16  monthOfDocumenting               80332 non-null  int64
#  17  weekOfDocumenting                80332 non-null  int64
#  18  dayOfDocumenting                 80332 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(4), object(6)
# memory usage: 11.6+ MB

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('minutes', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('tes', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('hours', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('hrs', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('hour', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('seconds', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('second', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('minute', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('min', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('sec', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('about', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('a few', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('approx', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('appx', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('possible', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('days', '')

# %%
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('.', '')
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('&', '')
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('#', '')
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('/', '')
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('<', '')
data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('>', '')
# Out:
# <ipython-input-180-099e99c45ad1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   data['described_duration_of_encounter'] = data['described_duration_of_encounter'].str.replace('.', '')

# %%
data
# Out:
#                 Date_time                  city state/province country  \
# 0     1949-10-10 20:30:00            san marcos             tx      us
# 1     1949-10-10 21:00:00          lackland afb             tx     NaN
# 2     1955-10-10 17:00:00  chester (uk/england)            NaN      gb
# 3     1956-10-10 21:00:00                  edna             tx      us
# 4     1960-10-10 20:00:00               kaneohe             hi      us
# ...                   ...                   ...            ...     ...
# 80327 2013-09-09 21:15:00             nashville             tn      us
# 80328 2013-09-09 22:00:00                 boise             id      us
# 80329 2013-09-09 22:00:00                  napa             ca      us
# 80330 2013-09-09 22:20:00                vienna             va      us
# 80331 2013-09-09 23:00:00                edmond             ok      us
#
#       UFO_shape  length_of_encounter_seconds described_duration_of_encounter  \
# 0      cylinder                       2700.0                             45
# 1         light                       7200.0                            1-2
# 2        circle                         20.0                             20
# 3        circle                         20.0                             12
# 4         light                        900.0                             15
# ...         ...                          ...                             ...
# 80327     light                        600.0                             10
# 80328    circle                       1200.0                             20
# 80329     other                       1200.0
# 80330    circle                          5.0                              5
# 80331     cigar                       1020.0                             17
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...      2004-04-27
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...      2005-12-16
# 2      Green/Orange circular disc over Chester&#44 En...      2008-01-21
# 3      My older brother and twin sister were leaving ...      2004-01-17
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...      2004-01-22
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...      2013-09-30
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...      2013-09-30
# 80329                                       Napa UFO&#44      2013-09-30
# 80330  Saw a five gold lit cicular craft moving fastl...      2013-09-30
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...      2013-09-30
#
#         latitude   longitude  yearOfSighting  monthOfSighting  weekOfSighting  \
# 0      29.883056  -97.941111          1949.0             10.0             0.0
# 1      29.384210  -98.581082          1949.0             10.0             0.0
# 2      53.200000   -2.916667          1955.0             10.0             0.0
# 3      28.978333  -96.645833          1956.0             10.0             2.0
# 4      21.418056 -157.803611          1960.0             10.0             0.0
# ...          ...         ...             ...              ...             ...
# 80327  36.165833  -86.784444          2013.0              9.0             0.0
# 80328  43.613611 -116.202500          2013.0              9.0             0.0
# 80329  38.297222 -122.284444          2013.0              9.0             0.0
# 80330  38.901111  -77.265556          2013.0              9.0             0.0
# 80331  35.652778  -97.477778          2013.0              9.0             0.0
#
#        dayOfSighting  yearOfDocumenting  monthOfDocumenting  \
# 0               10.0               2004                   4
# 1               10.0               2005                  12
# 2               10.0               2008                   1
# 3               10.0               2004                   1
# 4               10.0               2004                   1
# ...              ...                ...                 ...
# 80327            9.0               2013                   9
# 80328            9.0               2013                   9
# 80329            9.0               2013                   9
# 80330            9.0               2013                   9
# 80331            9.0               2013                   9
#
#        weekOfDocumenting  dayOfDocumenting
# 0                      1                27
# 1                      4                16
# 2                      0                21
# 3                      5                17
# 4                      3                22
# ...                  ...               ...
# 80327                  0                30
# 80328                  0                30
# 80329                  0                30
# 80330                  0                30
# 80331                  0                30
#
# [80332 rows x 19 columns]

# %%
# filling missing values
data.fillna(method = 'pad')
# Out:
#                 Date_time                  city state/province country  \
# 0     1949-10-10 20:30:00            san marcos             tx      us
# 1     1949-10-10 21:00:00          lackland afb             tx      us
# 2     1955-10-10 17:00:00  chester (uk/england)             tx      gb
# 3     1956-10-10 21:00:00                  edna             tx      us
# 4     1960-10-10 20:00:00               kaneohe             hi      us
# ...                   ...                   ...            ...     ...
# 80327 2013-09-09 21:15:00             nashville             tn      us
# 80328 2013-09-09 22:00:00                 boise             id      us
# 80329 2013-09-09 22:00:00                  napa             ca      us
# 80330 2013-09-09 22:20:00                vienna             va      us
# 80331 2013-09-09 23:00:00                edmond             ok      us
#
#       UFO_shape  length_of_encounter_seconds described_duration_of_encounter  \
# 0      cylinder                       2700.0                             45
# 1         light                       7200.0                            1-2
# 2        circle                         20.0                             20
# 3        circle                         20.0                             12
# 4         light                        900.0                             15
# ...         ...                          ...                             ...
# 80327     light                        600.0                             10
# 80328    circle                       1200.0                             20
# 80329     other                       1200.0
# 80330    circle                          5.0                              5
# 80331     cigar                       1020.0                             17
#
#                                              description date_documented  \
# 0      This event took place in early fall around 194...      2004-04-27
# 1      1949 Lackland AFB&#44 TX.  Lights racing acros...      2005-12-16
# 2      Green/Orange circular disc over Chester&#44 En...      2008-01-21
# 3      My older brother and twin sister were leaving ...      2004-01-17
# 4      AS a Marine 1st Lt. flying an FJ4B fighter/att...      2004-01-22
# ...                                                  ...             ...
# 80327  Round from the distance/slowly changing colors...      2013-09-30
# 80328  Boise&#44 ID&#44 spherical&#44 20 min&#44 10 r...      2013-09-30
# 80329                                       Napa UFO&#44      2013-09-30
# 80330  Saw a five gold lit cicular craft moving fastl...      2013-09-30
# 80331  2 witnesses 2  miles apart&#44 Red &amp; White...      2013-09-30
#
#         latitude   longitude  yearOfSighting  monthOfSighting  weekOfSighting  \
# 0      29.883056  -97.941111          1949.0             10.0             0.0
# 1      29.384210  -98.581082          1949.0             10.0             0.0
# 2      53.200000   -2.916667          1955.0             10.0             0.0
# 3      28.978333  -96.645833          1956.0             10.0             2.0
# 4      21.418056 -157.803611          1960.0             10.0             0.0
# ...          ...         ...             ...              ...             ...
# 80327  36.165833  -86.784444          2013.0              9.0             0.0
# 80328  43.613611 -116.202500          2013.0              9.0             0.0
# 80329  38.297222 -122.284444          2013.0              9.0             0.0
# 80330  38.901111  -77.265556          2013.0              9.0             0.0
# 80331  35.652778  -97.477778          2013.0              9.0             0.0
#
#        dayOfSighting  yearOfDocumenting  monthOfDocumenting  \
# 0               10.0               2004                   4
# 1               10.0               2005                  12
# 2               10.0               2008                   1
# 3               10.0               2004                   1
# 4               10.0               2004                   1
# ...              ...                ...                 ...
# 80327            9.0               2013                   9
# 80328            9.0               2013                   9
# 80329            9.0               2013                   9
# 80330            9.0               2013                   9
# 80331            9.0               2013                   9
#
#        weekOfDocumenting  dayOfDocumenting
# 0                      1                27
# 1                      4                16
# 2                      0                21
# 3                      5                17
# 4                      3                22
# ...                  ...               ...
# 80327                  0                30
# 80328                  0                30
# 80329                  0                30
# 80330                  0                30
# 80331                  0                30
#
# [80332 rows x 19 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Date_time                        79638 non-null  datetime64[ns]
#  1   city                             80332 non-null  object
#  2   state/province                   74535 non-null  object
#  3   country                          70662 non-null  object
#  4   UFO_shape                        78400 non-null  object
#  5   length_of_encounter_seconds      80329 non-null  float64
#  6   described_duration_of_encounter  80332 non-null  object
#  7   description                      80317 non-null  object
#  8   date_documented                  80332 non-null  datetime64[ns]
#  9   latitude                         80331 non-null  float64
#  10  longitude                        80332 non-null  float64
#  11  yearOfSighting                   79638 non-null  float64
#  12  monthOfSighting                  79638 non-null  float64
#  13  weekOfSighting                   79638 non-null  float64
#  14  dayOfSighting                    79638 non-null  float64
#  15  yearOfDocumenting                80332 non-null  int64
#  16  monthOfDocumenting               80332 non-null  int64
#  17  weekOfDocumenting                80332 non-null  int64
#  18  dayOfDocumenting                 80332 non-null  int64
# dtypes: datetime64[ns](2), float64(7), int64(4), object(6)
# memory usage: 11.6+ MB

# %% [markdown]
# ### Key Findings and Insights
